# %%
import pandas as pd

# Carregar o dataset tratado
df = pd.read_csv("../data/processed/portugal_real_estate_outliers_cleaned.csv")

# Exibir as primeiras linhas para conferir os dados
df.head()
# Out:
# C:\Users\Yan\AppData\Local\Temp\ipykernel_17788\1787395566.py:4: DtypeWarning: Columns (8,10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/processed/portugal_real_estate_outliers_cleaned.csv")
#       Price District                  City                  Town       Type  \
# 0  223000.0     Faro  São Brás de Alportel  São Brás de Alportel  Apartment
# 1  228000.0     Faro  São Brás de Alportel  São Brás de Alportel  Apartment
# 2  250000.0     Faro  São Brás de Alportel  São Brás de Alportel  Apartment
# 3  250000.0     Faro  São Brás de Alportel  São Brás de Alportel  Apartment
# 4  250000.0     Faro  São Brás de Alportel  São Brás de Alportel  Apartment
#
#   EnergyCertificate  TotalArea  Parking HasParking           ConstructionYear  \
# 0                A+       81.0      1.0       True  Informação não disponível
# 1                A+      108.0      1.0       True  Informação não disponível
# ...
